# %% [markdown]
# # MFDS_RS_Udemy

# %%
#!/usr/bin/env python
# coding: utf-8

# %%
import pandas as pd
import numpy as np
from datetime import date
import glob
import os
from os import path, listdir

import re
import nltk
#nltk.download('stopwords')
#nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
MFDS_dir = 'data/mfds/ds/'

# %%
tfdif = TfidfVectorizer(stop_words='english')

def recommend_jobs(search: str, item_count: int = 30) -> pd.DataFrame:
    jobs_list = pd.concat(
        [pd.Series([search]), data['Summary']],
        ignore_index=True
    )
    description_matrix = tfdif.fit_transform(jobs_list)
    similarity_matrix = linear_kernel(description_matrix)

    job_index = 0

    similarity_score = list(enumerate(similarity_matrix[job_index]))
    similarity_score = sorted(similarity_score, key=lambda x: x[1], reverse=True)
    similarity_score = similarity_score[1:item_count + 1]

    job_indices = [i[0] for i in similarity_score]
    return data.iloc[job_indices]

# %%
def load_data() -> pd.DataFrame:
    csv_files = [path.join(MFDS_dir, csv) for csv in listdir(MFDS_dir)]
    df = pd.concat(
        map(lambda csv: pd.read_csv(csv, index_col=0, encoding='latin1'), csv_files),
        #map(lambda csv: pd.read_csv(csv,  encoding='latin1'), csv_files),
        ignore_index=True
    )

    df['Summary'] = df['Summary'].fillna('')

    df.drop('PostDate', inplace=True, axis=1)

    return df

# %%
data = load_data()

data
# Out:
#                                                   title price  \
# 0     Professional Ruby on Rails Developer with Rails 5  1099
# 1     SQL for Beginners: The Easiest Way to Learn SQ...  1099
# 2                              Data Science Foundations   379
# 3                             Microsoft SQL from A to Z   749
# 4     Become a WordPress Developer: Unlocking Power ...  1099
# ...                                                 ...   ...
# 2454                                                NaN   NaN
# 2455                                                NaN   NaN
# 2456                                                NaN   NaN
# 2457                                                NaN   NaN
# 2458                                                NaN   NaN
#
#                                                     url              category  \
# 0                     /course/pro-ruby-on-rails-rails5/  ProgrammingLanguages
# 1                       /course/learn-sql-from-scratch/               backend
# 2                           /course/learn-data-science/           datascience
# 3                    /course/microsoft-sql-from-a-to-z/               backend
# 4     /course/become-a-wordpress-developer-php-javas...              frontend
# ...                                                 ...                   ...
# 2454  https://www.indeed.com/rc/clk?jk=05b9fb746a946...         cybersecurity
# 2455  https://www.indeed.com/rc/clk?jk=e3f0c47104471...         cybersecurity
# 2456  https://www.indeed.com/rc/clk?jk=abeba15d9461e...         cybersecurity
# 2457  https://www.indeed.com/rc/clk?jk=fcd395fa340c7...         cybersecurity
# 2458  https://www.indeed.com/rc/clk?jk=8d07e85d7ffed...         cybersecurity
#
#      rating language         instructor  \
# 0       4.7       en       Rob Percival
# 1       4.4       en  Code Star Academy
# 2       4.8       en          Data Hawk
# 3       4.5       en  Brewster Knowlton
# 4       4.7       en        Brad Schiff
# ...     ...      ...                ...
# 2454    NaN      NaN                NaN
# 2455    NaN      NaN                NaN
# 2456    NaN      NaN                NaN
# 2457    NaN      NaN                NaN
# 2458    NaN      NaN                NaN
#
#                                                 Summary  \
# 0     <p>Fully up-to-date fall-2017</p><p>The Profes...
# 1     <p>Welcome to the <strong>SQL for Beginners: T...
# 2     <p>Welcome to this course on Data Science.&nbs...
# 3     <p>This course is an extension of our previous...
# 4     <p>Unlock the full power of WordPress and go b...
# ...                                                 ...
# 2454  Active DoD security clearance at the TOP SECRE...
# 2455  This is a Merit-Exempt position and serves at ...
# 2456  The candidate will be involved in multiple asp...
# 2457  Review purchase requests for security implicat...
# 2458  System engineering and administration across a...
#
#                                                    tags platform  ...  \
# 0     expert, ruby, professional, basecamp, latest, ...    udemy  ...
# 1     instructors, expert, lectures, teaching, quizz...    udemy  ...
# 2     modern, talent, modeling, learning, hiring, ex...    udemy  ...
# 3     database, learning, lessons, server, teach, da...    udemy  ...
# 4     website, professor, hiring, 2019, wordpress, p...    udemy  ...
# ...                                                 ...      ...  ...
# 2454                                                NaN      NaN  ...
# 2455                                                NaN      NaN  ...
# 2456                                                NaN      NaN  ...
# 2457                                                NaN      NaN  ...
# 2458                                                NaN      NaN  ...
#
#      Unnamed: 74 Unnamed: 75 Unnamed: 76 Unnamed: 77 Unnamed: 78 Unnamed: 79  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 2454         NaN         NaN         NaN         NaN         NaN         NaN
# 2455         NaN         NaN         NaN         NaN         NaN         NaN
# 2456         NaN         NaN         NaN         NaN         NaN         NaN
# 2457         NaN         NaN         NaN         NaN         NaN         NaN
# 2458         NaN         NaN         NaN         NaN         NaN         NaN
#
#      Unnamed: 80                                           JobTitle  \
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            NaN                                                NaN
# ...          ...                                                ...
# 2454         NaN                          Systems Security Engineer
# 2455         NaN                         Internal Audit Manager, IT
# 2456         NaN       Cloud Security Controls Engineer - Associate
# 2457         NaN  Enterprise Security - Audit and Compliance Ana...
# 2458         NaN  Information Systems Security Officer (Government)
#
#                           Company           Location
# 0                             NaN                NaN
# 1                             NaN                NaN
# 2                             NaN                NaN
# 3                             NaN                NaN
# 4                             NaN                NaN
# ...                           ...                ...
# 2454  LOCKHEED MARTIN CORPORATION     Moorestown, NJ
# 2455            DeKalb County, GA  DeKalb County, GA
# 2456               Morgan Stanley      Baltimore, MD
# 2457                    MIB Group      Braintree, MA
# 2458                         AT&T    San Antonio, TX
#
# [2459 rows x 83 columns]

# %%
results = recommend_jobs("python")

results
# Out:
#                                                  title  \
# 357  Complete Python Bootcamp For Everyone From Zer...
# 264  Bootcamp de Desarrollo Web - En espaÃ±ol - Ful...
# 296  Complete Website Design Bootcamp! Front-End We...
# 139  CompTIA Security+ (SY0-601) Complete Course & ...
# 284  Advanced Ethical Hacking: Network & Web PenTes...
# 356  Full Stack Data Science with Python, Numpy and...
# 292  Despliegue de Proyecto de Node.js en Amazon We...
# 146         Beat the Codility Coding Interview in Ruby
# 558  Apply Jobs as MERN stack developer with this c...
# 668      C_CPI_14, SAP Integration Suite Practice Exam
# 542  Curso Completo de Data Science en Python Desde...
# 481  NodeJS complete course, Node JS & Express JS f...
# 483  Master Cyber Security, A Step-by-Step Guide fo...
# 504                Data Structures & Algorithms - Java
# 996                                                NaN
# 411                                            MongoDB
# 33      Postman: The Complete Guide - REST API Testing
# 242  Spring Boot REST & Angular + Full Stack Applic...
# 200  Sistema de encuestas con Spring boot MVC y MyS...
# 401                               mern stack portfolio
# 226  React, NodeJS, Express & MongoDB - The MERN Fu...
# 355      Data Science with R and Python, R Programming
# 484  Data Structures & Algorithms Essentials using ...
# 306  How to develop a productive HTTP client in Gol...
# 318  Advanced Ethical Hacking: Network & Web PenTes...
# 543  Escuela de ProgramaciÃ³n y Desarrollo Web desd...
# 601  Full Mern Stack Project with MongoDB, Express,...
# 288  Learn Ethical Hacking From A-Z: Beginner To Ex...
# 160  Software Testing Masterclass (2022) - From Nov...
# 561  Datawarehouse, Linux, NoSQL, MongoDB - Job Int...
#
#                                                  price  \
# 357                                               1099
# 264                                               1099
# 296                                               1099
# 139                                               1099
# 284                                                749
# 356                                               1099
# 292                                                649
# 146                                                379
# 558                                               1099
# 668                                                379
# 542                                                449
# 481                                               1099
# 483                                                379
# 504                                                999
# 996                                                NaN
# 411   + more)|1399|/course/complete-nodejs-develope...
# 33                                                 379
# 242                                               1099
# 200                                                379
# 401                                                379
# 226                                               1099
# 355                                               1099
# 484                                               1099
# 306                                                449
# 318                                                749
# 543                                                379
# 601                                               1099
# 288                                               1099
# 160                                                999
# 561                                                899
#
#                                                    url  \
# 357                        /course/python-foreveryone/
# 264                /course/bootcamp-de-desarrollo-web/
# 296  /course/practical-web-developer-bootcamp-zero-...
# 139                              /course/securityplus/
# 284  /course/advanced-ethical-hacking-network-web-p...
# 356  /course/full-stack-data-science-with-python-nu...
# 292            /course/despliegue-proyecto-nodejs-aws/
# 146  /course/beat-the-codility-coding-interview-in-...
# 558  /course/apply-jobs-as-mern-stack-developer-wit...
# 668  /course/c_cpi_14-sap-integration-suite-practic...
# 542  /course/curso-completo-de-data-science-en-pyth...
# 481  /course/the-complete-nodejs-express-with-nodej...
# 483  /course/master-cyber-security-a-step-by-step-g...
# 504       /course/data-structures-and-algorithms-java/
# 996  https://www.indeed.com/rc/clk?jk=784f18c4dd297...
# 411  000+ developers and a course taught by industr...
# 33                 /course/postman-the-complete-guide/
# 242  /course/spring-boot-rest-angular-full-stack-ap...
# 200  /course/crear-sistema-de-encuestas-con-spring-...
# 401                      /course/mern-stack-portfolio/
# 226  /course/react-nodejs-express-mongodb-the-mern-...
# 355      /course/full-stack-data-science-r-and-python/
# 484  /course/cpp-data-structures-algorithms-prateek...
# 306  /course/how-to-develop-a-productive-http-clien...
# 318  /course/advanced-ethical-hacking-network-web-p...
# 543               /course/programacion-desarrollo-web/
# 601  /course/full-mern-stack-project-with-mongodb-e...
# 288  /course/learn-ethical-hacking-from-a-z-beginne...
# 160  /course/software-testing-masterclass-from-novi...
# 561  /course/dwh-linux-nosql-mongodb-job-interview-...
#
#                                               category        rating  \
# 357                                           frontend           4.6
# 264                                           frontend           4.6
# 296                                           frontend           4.3
# 139                                      cybersecurity           4.7
# 284                                      cybersecurity             4
# 356                                        datascience           4.5
# 292                                           frontend           4.8
# 146                               ProgrammingLanguages           4.1
# 558                                          fullstack           4.5
# 668                               ProgrammingLanguages           4.7
# 542                                        datascience           4.6
# 481                                          fullstack           4.5
# 483                                      cybersecurity           4.9
# 504                               ProgrammingLanguages           4.6
# 996                                            backend           NaN
# 411   this course is focused on efficiency and turn...   out of date
# 33                                            frontend           4.6
# 242                                          fullstack           4.4
# 200                                          fullstack           4.4
# 401                                          fullstack           4.7
# 226                                           frontend           4.5
# 355                                        datascience           4.8
# 484                                            backend           4.4
# 306                               ProgrammingLanguages           4.3
# 318                                      cybersecurity             4
# 543                                            backend           4.6
# 601                                          fullstack           4.4
# 288                                      cybersecurity           4.3
# 160                                            backend           4.4
# 561                                            backend           4.9
#
#                                               language  \
# 357                                                 en
# 264                                                 es
# 296                                                 en
# 139                                                 en
# 284                                                 en
# 356                                                 en
# 292                                                 es
# 146                                                 en
# 558                                                 en
# 668                                                 en
# 542                                                 es
# 481                                                 en
# 483                                                 en
# 504                                                 en
# 996                                                NaN
# 411   incomplete tutorials anymore! <strong>Graduat...
# 33                                                  en
# 242                                                 en
# 200                                                 es
# 401                                                 en
# 226                                                 en
# 355                                                 en
# 484                                                 en
# 306                                                 en
# 318                                                 en
# 543                                                 es
# 601                                                 en
# 288                                                 en
# 160                                                 en
# 561                                                 en
#
#                                           instructor  \
# 357                                   Elshad Karimov
# 264                                      Alan Wagner
# 296                                    Emenwa Global
# 139  Jason Dion â¢ 1 Million+ Enrollments Worldwide
# 284                            JRDcademy Institution
# 356                                      Oak Academy
# 292                                Jeovani MartÃ­nez
# 146                                    James Cutajar
# 558                                 Obify Consulting
# 668                                  Ramesh Vairavan
# 542                                    Frank Andrade
# 481                                      Oak Academy
# 483                                          R Tutor
# 504                                    Scott Barrett
# 996                                              NaN
# 411                                            Tesla
# 33                                    Valentin Despa
# 242                                     Karthikeya T
# 200                          Alex Joel Pagoada Suazo
# 401                                   Odysseas kolas
# 226           Academind by Maximilian SchwarzmÃ¼ller
# 355                                      Oak Academy
# 484                                   Prateek Narang
# 306                                   Federico LeÃ³n
# 318                            JRDcademy Institution
# 543                                    Alex Roel ChB
# 601                                      Oak Academy
# 288                                   Juan E. Galvan
# 160                                       Ozan Ilhan
# 561                             Ultimate Study Stuff
#
#                                                Summary  \
# 357  <p>Welcome to Complete Python Bootcamp for Eve...
# 264  <p>Este curso estÃ¡ pensado para alumnos con c...
# 296  <p>In this course, you will learn the specific...
# 139  <p><strong>** Taught by a Best Selling IT Cert...
# 284  <p>This course is all about Ethical Hacking an...
# 356  <p>Hello Dear,</p><p>Welcome to <strong>Full S...
# 292  <p>Amazon Web Services (AWS) es una de las pri...
# 146  <p><strong>This course has been designed to he...
# 558  <p>In this course, you will learn everything t...
# 668  <p>The SAP Certified Development Associate - S...
# 542  <p>Bienvenidos a este Curso Completo de Data S...
# 481  <p><strong>This course is fully up-to-date wit...
# 483  <p>Hello there, </p><p>Welcome to the <strong>...
# 504  <p><strong>This course is differentâ¦</strong...
# 996  Along with other developers, the Full Stack De...
# 411                                             Amazon
# 33   <p>RESTful APIs (or simply REST API) are every...
# 242  <p><strong>Are you looking for a Job, and your...
# 200  <p>En este curso crearemos un sistema de encue...
# 401  <p>In this course you are going to cover all t...
# 226  <p>We built the<strong> bestselling React</str...
# 355  <p>Welcome to <strong>Data Science with R and ...
# 484  <p>Are you a <strong>beginner</strong> looking...
# 306  <p>Have you ever called a REST&nbsp;API from y...
# 318  <p>This course is all about Ethical Hacking an...
# 543  <p><strong>Bienvenido a la Escuela de Programa...
# 601  <p>mern, mern stack, mern full stack, react, n...
# 288  <p>Welcome to - Learn Ethical Hacking From A-Z...
# 160  <p>Welcome to the <strong>Complete Software Te...
# 561  <p><strong><em>Looking for an perfect job inte...
#
#                                                   tags platform  ...  \
# 357  microsoft, sqlite, startup, instagram, snake, ...    udemy  ...
# 264  proyectos, trabajo, usadas, tecnologÃ­as, desa...    udemy  ...
# 296  students, classes, instructors, technologies, ...    udemy  ...
# 139  master, love, computer, completed, exam, linux...    udemy  ...
# 284  algorithms, cyber, security, hacking, tutorial...    udemy  ...
# 356  learn, hello, learning, welcome, automation, p...    udemy  ...
# 292  certificado, escalabilidad, tecnologÃ­a, conoc...    udemy  ...
# 146  skills, test, learn, coding, practice, intervi...    udemy  ...
# 558  studio, pro, learn, onload, developer, decrypt...    udemy  ...
# 668  integration, tested, certification, certified,...    udemy  ...
# 542  tÃ©cnicas, tutoriales, pandas, scientist, scie...    udemy  ...
# 481  advanced, 2017, detailed, modern, thorough, fu...    udemy  ...
# 483  stackoverflow, browser, java, php, html, webma...    udemy  ...
# 504  big, updated, advantages, beginner, students, ...    udemy  ...
# 996                                                NaN      NaN  ...
# 411                                              Apple      IBM  ...
# 33   cookies, app, server, strong, http, headers, c...    udemy  ...
# 242  teaching, requisite, teamplate, trainer, class...    udemy  ...
# 200  crearemos, contara, proporcionara, aprenderemo...    udemy  ...
# 401  stack, dynamic, add, strong, admin, developmen...    udemy  ...
# 226  upload, nodejs, technologies, hosting, build, ...    udemy  ...
# 355  tutorial, scientist, mathematics, django, tuto...    udemy  ...
# 484  expert, google, engineer, mentored, algorithms...    udemy  ...
# 306  requests, interface, timeouts, applications, c...    udemy  ...
# 318  algorithms, cyber, security, hacking, tutorial...    udemy  ...
# 543  django, flexbox, apps, java, web, manipulando,...    udemy  ...
# 601  hands, project, stack, node, development, mong...    udemy  ...
# 288  mouse, party, webcam, apps, lab, password, hac...    udemy  ...
# 160  lecture, testrail, teach, lessons, instructor,...    udemy  ...
# 561  working, test, software, tests, job, web, inte...    udemy  ...
#
#     Unnamed: 74 Unnamed: 75 Unnamed: 76 Unnamed: 77 Unnamed: 78 Unnamed: 79  \
# 357         NaN         NaN         NaN         NaN         NaN         NaN
# 264         NaN         NaN         NaN         NaN         NaN         NaN
# 296         NaN         NaN         NaN         NaN         NaN         NaN
# 139         NaN         NaN         NaN         NaN         NaN         NaN
# 284         NaN         NaN         NaN         NaN         NaN         NaN
# 356         NaN         NaN         NaN         NaN         NaN         NaN
# 292         NaN         NaN         NaN         NaN         NaN         NaN
# 146         NaN         NaN         NaN         NaN         NaN         NaN
# 558         NaN         NaN         NaN         NaN         NaN         NaN
# 668         NaN         NaN         NaN         NaN         NaN         NaN
# 542         NaN         NaN         NaN         NaN         NaN         NaN
# 481         NaN         NaN         NaN         NaN         NaN         NaN
# 483         NaN         NaN         NaN         NaN         NaN         NaN
# 504         NaN         NaN         NaN         NaN         NaN         NaN
# 996         NaN         NaN         NaN         NaN         NaN         NaN
# 411      spacex       tesla      2023.0     startup      google    bootcamp
# 33          NaN         NaN         NaN         NaN         NaN         NaN
# 242         NaN         NaN         NaN         NaN         NaN         NaN
# 200         NaN         NaN         NaN         NaN         NaN         NaN
# 401         NaN         NaN         NaN         NaN         NaN         NaN
# 226         NaN         NaN         NaN         NaN         NaN         NaN
# 355         NaN         NaN         NaN         NaN         NaN         NaN
# 484         NaN         NaN         NaN         NaN         NaN         NaN
# 306         NaN         NaN         NaN         NaN         NaN         NaN
# 318         NaN         NaN         NaN         NaN         NaN         NaN
# 543         NaN         NaN         NaN         NaN         NaN         NaN
# 601         NaN         NaN         NaN         NaN         NaN         NaN
# 288         NaN         NaN         NaN         NaN         NaN         NaN
# 160         NaN         NaN         NaN         NaN         NaN         NaN
# 561         NaN         NaN         NaN         NaN         NaN         NaN
#
#              Unnamed: 80              JobTitle    Company Location
# 357                  NaN                   NaN        NaN      NaN
# 264                  NaN                   NaN        NaN      NaN
# 296                  NaN                   NaN        NaN      NaN
# 139                  NaN                   NaN        NaN      NaN
# 284                  NaN                   NaN        NaN      NaN
# 356                  NaN                   NaN        NaN      NaN
# 292                  NaN                   NaN        NaN      NaN
# 146                  NaN                   NaN        NaN      NaN
# 558                  NaN                   NaN        NaN      NaN
# 668                  NaN                   NaN        NaN      NaN
# 542                  NaN                   NaN        NaN      NaN
# 481                  NaN                   NaN        NaN      NaN
# 483                  NaN                   NaN        NaN      NaN
# 504                  NaN                   NaN        NaN      NaN
# 996                  NaN  Full Stack Developer  MyVillage   Remote
# 411   startupshtml|udemy                   NaN        NaN      NaN
# 33                   NaN                   NaN        NaN      NaN
# 242                  NaN                   NaN        NaN      NaN
# 200                  NaN                   NaN        NaN      NaN
# 401                  NaN                   NaN        NaN      NaN
# 226                  NaN                   NaN        NaN      NaN
# 355                  NaN                   NaN        NaN      NaN
# 484                  NaN                   NaN        NaN      NaN
# 306                  NaN                   NaN        NaN      NaN
# 318                  NaN                   NaN        NaN      NaN
# 543                  NaN                   NaN        NaN      NaN
# 601                  NaN                   NaN        NaN      NaN
# 288                  NaN                   NaN        NaN      NaN
# 160                  NaN                   NaN        NaN      NaN
# 561                  NaN                   NaN        NaN      NaN
#
# [30 rows x 83 columns]
